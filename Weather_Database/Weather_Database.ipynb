# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import datetime module
from datetime import datetime

# Note: To make these run successfully again, note that config.py and _pycache_ were deleted from file.

# %%
# Create set of random lat and long combinations
lats= np.random.uniform(low= -90.000, high= 90.000, size=2000)
lngs= np.random.uniform(low =-180.000, high= 180.00, size=2000)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
# Add lat/lng to list
coordinates= list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Import API key
from config import weather_api_key

# %%
# Build basic URL for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list for eather data
city_data=[]

# Print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_desc= city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": weather_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Loop through all cities in list
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50== 0 and i>50):
        set_count +=1
        record_count =1
    # Create endpoint URL wiht each city
    city_url= url+ "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | itoman
# Processing Record 3 of Set 1 | komatipoort
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | turbat
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | goderich
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | feuchtwangen
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | kamaishi
# Processing Record 19 of Set 1 | abu kamal
# Processing Record 20 of Set 1 | tlahualilo
# City not found. Skipping...
# Processing Record 21 of Set 1 | san ramon
# Processing Record 22 of Set 1 | baruun-urt
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | riccione
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | phalaborwa
# Processing Record 31 of Set 1 | hatillo
# Processing Record 32 of Set 1 | mandalgovi
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | taitung
# Processing Record 35 of Set 1 | mehamn
# Processing Record 36 of Set 1 | saldanha
# Processing Record 37 of Set 1 | tommot
# Processing Record 38 of Set 1 | san jose
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | faya
# Processing Record 41 of Set 1 | oschersleben
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | wonthaggi
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | boa vista
# Processing Record 47 of Set 1 | yurimaguas
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | kupang
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | constitucion
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | dubbo
# Processing Record 4 of Set 2 | alice springs
# Processing Record 5 of Set 2 | deputatskiy
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | yarada
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | kenai
# Processing Record 10 of Set 2 | dunedin
# Processing Record 11 of Set 2 | shingu
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | dzerzhinskoye
# Processing Record 14 of Set 2 | bella union
# Processing Record 15 of Set 2 | bilibino
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | belaya gora
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | amahai
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | geraldton
# Processing Record 22 of Set 2 | vostok
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | mishelevka
# Processing Record 25 of Set 2 | mahasamund
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | nanortalik
# Processing Record 29 of Set 2 | tuatapere
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | norman wells
# Processing Record 33 of Set 2 | parksville
# Processing Record 34 of Set 2 | vytegra
# Processing Record 35 of Set 2 | saint-georges
# Processing Record 36 of Set 2 | luwuk
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 2 | meulaboh
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | rustenburg
# Processing Record 43 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 2 | nhulunbuy
# Processing Record 45 of Set 2 | kitob
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | angoram
# Processing Record 3 of Set 3 | balykshi
# Processing Record 4 of Set 3 | sawtell
# Processing Record 5 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | hit
# Processing Record 8 of Set 3 | santa cruz
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | sitka
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 3 | da lat
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | la rioja
# Processing Record 17 of Set 3 | hendaye
# Processing Record 18 of Set 3 | san quintin
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | chimbote
# Processing Record 21 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 3 | sinnamary
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | mahanoro
# Processing Record 25 of Set 3 | midland
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | yangambi
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | pangoa
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | port-cartier
# Processing Record 32 of Set 3 | loreto
# Processing Record 33 of Set 3 | strezhevoy
# Processing Record 34 of Set 3 | verkhnyaya inta
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | torrevieja
# Processing Record 37 of Set 3 | cody
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | hervey bay
# Processing Record 40 of Set 3 | chittaurgarh
# Processing Record 41 of Set 3 | bam
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | gat
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | nabire
# Processing Record 47 of Set 3 | ushtobe
# Processing Record 48 of Set 3 | sarangani
# Processing Record 49 of Set 3 | lagos
# Processing Record 50 of Set 3 | ambulu
# Processing Record 1 of Set 4 | turukhansk
# Processing Record 2 of Set 4 | oum hadjer
# Processing Record 3 of Set 4 | leh
# Processing Record 4 of Set 4 | buchanan
# Processing Record 5 of Set 4 | sioux falls
# Processing Record 6 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 4 | natal
# Processing Record 8 of Set 4 | zamora
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | hay river
# Processing Record 11 of Set 4 | itacarambi
# Processing Record 12 of Set 4 | nome
# Processing Record 13 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | cururupu
# Processing Record 16 of Set 4 | bontang
# Processing Record 17 of Set 4 | inta
# Processing Record 18 of Set 4 | thompson
# Processing Record 19 of Set 4 | aktau
# Processing Record 20 of Set 4 | shadrinsk
# Processing Record 21 of Set 4 | bathsheba
# Processing Record 22 of Set 4 | husavik
# Processing Record 23 of Set 4 | dongzhen
# Processing Record 24 of Set 4 | vestmannaeyjar
# Processing Record 25 of Set 4 | angoche
# Processing Record 26 of Set 4 | butajira
# Processing Record 27 of Set 4 | karakol
# Processing Record 28 of Set 4 | tecate
# Processing Record 29 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 4 | melfi
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | new ulm
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | pouebo
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | kryve ozero
# Processing Record 39 of Set 4 | namatanai
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | noumea
# Processing Record 42 of Set 4 | pinotepa nacional
# Processing Record 43 of Set 4 | do gonbadan
# Processing Record 44 of Set 4 | adrar
# Processing Record 45 of Set 4 | ust-kuyga
# Processing Record 46 of Set 4 | kununurra
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | baykit
# Processing Record 49 of Set 4 | ust-barguzin
# Processing Record 50 of Set 4 | totness
# Processing Record 1 of Set 5 | durban
# Processing Record 2 of Set 5 | chase
# Processing Record 3 of Set 5 | tual
# Processing Record 4 of Set 5 | camacha
# Processing Record 5 of Set 5 | bengkulu
# Processing Record 6 of Set 5 | port elizabeth
# Processing Record 7 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 8 of Set 5 | nelson bay
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | mantua
# Processing Record 11 of Set 5 | bilma
# Processing Record 12 of Set 5 | kaili
# Processing Record 13 of Set 5 | salgado
# Processing Record 14 of Set 5 | moose factory
# Processing Record 15 of Set 5 | play cu
# City not found. Skipping...
# Processing Record 16 of Set 5 | bolgatanga
# Processing Record 17 of Set 5 | nisia floresta
# Processing Record 18 of Set 5 | terrace bay
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | matamoros
# Processing Record 21 of Set 5 | padang
# Processing Record 22 of Set 5 | alta floresta
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | mayo
# Processing Record 25 of Set 5 | gavle
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | saint-philippe
# Processing Record 28 of Set 5 | la victoria
# Processing Record 29 of Set 5 | villa guerrero
# Processing Record 30 of Set 5 | hamilton
# Processing Record 31 of Set 5 | sanjwal
# Processing Record 32 of Set 5 | trincomalee
# Processing Record 33 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 5 | provideniya
# Processing Record 35 of Set 5 | hami
# Processing Record 36 of Set 5 | kruisfontein
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | viedma
# Processing Record 39 of Set 5 | igarka
# Processing Record 40 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 41 of Set 5 | kolosovka
# Processing Record 42 of Set 5 | amparafaravola
# Processing Record 43 of Set 5 | colares
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | kananga
# Processing Record 46 of Set 5 | warrnambool
# Processing Record 47 of Set 5 | aswan
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | skovorodino
# Processing Record 50 of Set 5 | emerald
# Processing Record 1 of Set 6 | marawi
# Processing Record 2 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 6 | timra
# Processing Record 4 of Set 6 | sola
# Processing Record 5 of Set 6 | ozuluama
# Processing Record 6 of Set 6 | tautira
# Processing Record 7 of Set 6 | lata
# Processing Record 8 of Set 6 | kahului
# Processing Record 9 of Set 6 | lasa
# Processing Record 10 of Set 6 | okha
# Processing Record 11 of Set 6 | ardakan
# Processing Record 12 of Set 6 | la tuque
# Processing Record 13 of Set 6 | marshalltown
# Processing Record 14 of Set 6 | dingle
# Processing Record 15 of Set 6 | chokwe
# Processing Record 16 of Set 6 | souillac
# Processing Record 17 of Set 6 | kavieng
# Processing Record 18 of Set 6 | yar-sale
# Processing Record 19 of Set 6 | santa catarina mita
# Processing Record 20 of Set 6 | mubende
# Processing Record 21 of Set 6 | paita
# Processing Record 22 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 23 of Set 6 | norsup
# Processing Record 24 of Set 6 | maceio
# Processing Record 25 of Set 6 | porto novo
# Processing Record 26 of Set 6 | mirnyy
# Processing Record 27 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 6 | linhai
# Processing Record 29 of Set 6 | coihaique
# Processing Record 30 of Set 6 | ahipara
# Processing Record 31 of Set 6 | san ignacio
# Processing Record 32 of Set 6 | saint-joseph
# Processing Record 33 of Set 6 | yulara
# Processing Record 34 of Set 6 | jiwani
# Processing Record 35 of Set 6 | bhum
# Processing Record 36 of Set 6 | fort nelson
# Processing Record 37 of Set 6 | fenoarivo
# Processing Record 38 of Set 6 | silver city
# Processing Record 39 of Set 6 | ghansor
# Processing Record 40 of Set 6 | vila
# Processing Record 41 of Set 6 | mitu
# Processing Record 42 of Set 6 | tema
# Processing Record 43 of Set 6 | yeppoon
# Processing Record 44 of Set 6 | harper
# Processing Record 45 of Set 6 | jampur
# Processing Record 46 of Set 6 | makakilo city
# Processing Record 47 of Set 6 | poum
# Processing Record 48 of Set 6 | homa bay
# Processing Record 49 of Set 6 | katobu
# Processing Record 50 of Set 6 | sioux lookout
# Processing Record 1 of Set 7 | taltal
# Processing Record 2 of Set 7 | iskateley
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | uzhur
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | kresttsy
# Processing Record 7 of Set 7 | tupik
# Processing Record 8 of Set 7 | inhambane
# Processing Record 9 of Set 7 | marystown
# Processing Record 10 of Set 7 | luderitz
# Processing Record 11 of Set 7 | quatre cocos
# Processing Record 12 of Set 7 | teofilo otoni
# Processing Record 13 of Set 7 | lake city
# Processing Record 14 of Set 7 | kuznechnoye
# Processing Record 15 of Set 7 | north bend
# Processing Record 16 of Set 7 | lodja
# Processing Record 17 of Set 7 | banda aceh
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | moura
# Processing Record 20 of Set 7 | hun
# Processing Record 21 of Set 7 | hasaki
# Processing Record 22 of Set 7 | codrington
# Processing Record 23 of Set 7 | tokonou
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | joshimath
# Processing Record 26 of Set 7 | champerico
# Processing Record 27 of Set 7 | ketchikan
# Processing Record 28 of Set 7 | bloomfield
# Processing Record 29 of Set 7 | bridlington
# Processing Record 30 of Set 7 | lac du bonnet
# Processing Record 31 of Set 7 | talcahuano
# Processing Record 32 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | kysyl-syr
# Processing Record 34 of Set 7 | oistins
# Processing Record 35 of Set 7 | ponta do sol
# Processing Record 36 of Set 7 | anjar
# Processing Record 37 of Set 7 | great falls
# Processing Record 38 of Set 7 | vila velha
# Processing Record 39 of Set 7 | buin
# Processing Record 40 of Set 7 | niono
# Processing Record 41 of Set 7 | walvis bay
# Processing Record 42 of Set 7 | cidreira
# Processing Record 43 of Set 7 | mount gambier
# Processing Record 44 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | longyan
# Processing Record 46 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 7 | lazaro cardenas
# Processing Record 48 of Set 7 | kathmandu
# Processing Record 49 of Set 7 | kungurtug
# Processing Record 50 of Set 7 | zomin
# Processing Record 1 of Set 8 | antalya
# Processing Record 2 of Set 8 | kaitangata
# Processing Record 3 of Set 8 | hobyo
# Processing Record 4 of Set 8 | newcastle
# Processing Record 5 of Set 8 | amazar
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | leningradskiy
# Processing Record 8 of Set 8 | haapiti
# Processing Record 9 of Set 8 | sandpoint
# Processing Record 10 of Set 8 | beypur
# City not found. Skipping...
# Processing Record 11 of Set 8 | ormara
# Processing Record 12 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 8 | vidim
# Processing Record 14 of Set 8 | rypefjord
# Processing Record 15 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 8 | kiruna
# Processing Record 17 of Set 8 | chagoda
# Processing Record 18 of Set 8 | kattivakkam
# Processing Record 19 of Set 8 | erdenet
# Processing Record 20 of Set 8 | eureka
# Processing Record 21 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | sorland
# Processing Record 24 of Set 8 | maneadero
# Processing Record 25 of Set 8 | jiazi
# Processing Record 26 of Set 8 | srednekolymsk
# Processing Record 27 of Set 8 | brae
# Processing Record 28 of Set 8 | lorengau
# Processing Record 29 of Set 8 | haines junction
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | muslyumovo
# Processing Record 32 of Set 8 | qaqortoq
# Processing Record 33 of Set 8 | pacifica
# Processing Record 34 of Set 8 | sao gabriel da cachoeira
# Processing Record 35 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 8 | khash
# Processing Record 37 of Set 8 | lovozero
# Processing Record 38 of Set 8 | port victoria
# Processing Record 39 of Set 8 | trinidad
# Processing Record 40 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | creston
# Processing Record 43 of Set 8 | sao jose da coroa grande
# Processing Record 44 of Set 8 | kuytun
# Processing Record 45 of Set 8 | katha
# City not found. Skipping...
# Processing Record 46 of Set 8 | solntsevo
# Processing Record 47 of Set 8 | neryungri
# Processing Record 48 of Set 8 | marsh harbour
# Processing Record 49 of Set 8 | karratha
# Processing Record 50 of Set 8 | izhma
# Processing Record 1 of Set 9 | simplicio mendes
# Processing Record 2 of Set 9 | yeovil
# Processing Record 3 of Set 9 | lazurne
# Processing Record 4 of Set 9 | sawankhalok
# Processing Record 5 of Set 9 | saint george
# Processing Record 6 of Set 9 | westport
# Processing Record 7 of Set 9 | koungou
# Processing Record 8 of Set 9 | sao desiderio
# Processing Record 9 of Set 9 | whitehorse
# Processing Record 10 of Set 9 | kushnarenkovo
# Processing Record 11 of Set 9 | mtsamboro
# Processing Record 12 of Set 9 | matagami
# Processing Record 13 of Set 9 | manokwari
# Processing Record 14 of Set 9 | ixtapa
# Processing Record 15 of Set 9 | nishihara
# Processing Record 16 of Set 9 | comodoro rivadavia
# Processing Record 17 of Set 9 | chumikan
# Processing Record 18 of Set 9 | ajdabiya
# Processing Record 19 of Set 9 | verkhnevilyuysk
# Processing Record 20 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 9 | erikoussa
# City not found. Skipping...
# Processing Record 22 of Set 9 | celestun
# Processing Record 23 of Set 9 | san cristobal
# Processing Record 24 of Set 9 | nantucket
# Processing Record 25 of Set 9 | dauriya
# Processing Record 26 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 9 | ojinaga
# Processing Record 28 of Set 9 | vesoul
# Processing Record 29 of Set 9 | kumluca
# Processing Record 30 of Set 9 | brooks
# Processing Record 31 of Set 9 | yerbogachen
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | orsha
# Processing Record 34 of Set 9 | fukue
# Processing Record 35 of Set 9 | chicama
# Processing Record 36 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 9 | atar
# Processing Record 38 of Set 9 | rocha
# Processing Record 39 of Set 9 | klaksvik
# Processing Record 40 of Set 9 | el reno
# Processing Record 41 of Set 9 | rawson
# Processing Record 42 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 9 | aripuana
# Processing Record 44 of Set 9 | bubaque
# Processing Record 45 of Set 9 | yaan
# Processing Record 46 of Set 9 | tecpan
# Processing Record 47 of Set 9 | canico
# Processing Record 48 of Set 9 | sabang
# Processing Record 49 of Set 9 | olinda
# Processing Record 50 of Set 9 | pipri
# Processing Record 1 of Set 10 | hokitika
# Processing Record 2 of Set 10 | tsiroanomandidy
# Processing Record 3 of Set 10 | najran
# Processing Record 4 of Set 10 | palmer
# Processing Record 5 of Set 10 | kargopol
# Processing Record 6 of Set 10 | sorong
# Processing Record 7 of Set 10 | barra
# Processing Record 8 of Set 10 | jiujiang
# Processing Record 9 of Set 10 | houlton
# Processing Record 10 of Set 10 | talnakh
# Processing Record 11 of Set 10 | huicungo
# Processing Record 12 of Set 10 | saint-paul-les-dax
# Processing Record 13 of Set 10 | pryluky
# Processing Record 14 of Set 10 | grand gaube
# Processing Record 15 of Set 10 | beloha
# Processing Record 16 of Set 10 | puerto escondido
# Processing Record 17 of Set 10 | tuy hoa
# Processing Record 18 of Set 10 | kichera
# Processing Record 19 of Set 10 | chaman
# Processing Record 20 of Set 10 | phalodi
# Processing Record 21 of Set 10 | komsomolskiy
# Processing Record 22 of Set 10 | mount isa
# Processing Record 23 of Set 10 | guanagazapa
# Processing Record 24 of Set 10 | te anau
# Processing Record 25 of Set 10 | high level
# Processing Record 26 of Set 10 | abalak
# Processing Record 27 of Set 10 | pisco
# Processing Record 28 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 10 | sindor
# Processing Record 30 of Set 10 | grindavik
# Processing Record 31 of Set 10 | kuruman
# Processing Record 32 of Set 10 | rurrenabaque
# Processing Record 33 of Set 10 | lida
# Processing Record 34 of Set 10 | sao joao da barra
# Processing Record 35 of Set 10 | atagay
# Processing Record 36 of Set 10 | kem
# Processing Record 37 of Set 10 | iwanai
# Processing Record 38 of Set 10 | havre-saint-pierre
# Processing Record 39 of Set 10 | pochinok
# Processing Record 40 of Set 10 | vila franca do campo
# Processing Record 41 of Set 10 | cairns
# Processing Record 42 of Set 10 | altamont
# Processing Record 43 of Set 10 | zhuhai
# Processing Record 44 of Set 10 | saint-pierre
# Processing Record 45 of Set 10 | yaviza
# Processing Record 46 of Set 10 | nagornyy
# Processing Record 47 of Set 10 | okhotsk
# Processing Record 48 of Set 10 | sidi ali
# Processing Record 49 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 10 | aitape
# Processing Record 1 of Set 11 | marzuq
# Processing Record 2 of Set 11 | chamba
# Processing Record 3 of Set 11 | iqaluit
# Processing Record 4 of Set 11 | sibut
# Processing Record 5 of Set 11 | omsukchan
# Processing Record 6 of Set 11 | torres
# Processing Record 7 of Set 11 | hovd
# Processing Record 8 of Set 11 | byron bay
# Processing Record 9 of Set 11 | clyde river
# Processing Record 10 of Set 11 | faanui
# Processing Record 11 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 11 | veraval
# Processing Record 13 of Set 11 | zhumadian
# Processing Record 14 of Set 11 | alexandria
# Processing Record 15 of Set 11 | sibolga
# Processing Record 16 of Set 11 | puerto madryn
# Processing Record 17 of Set 11 | doka
# Processing Record 18 of Set 11 | yenagoa
# Processing Record 19 of Set 11 | belyy yar
# Processing Record 20 of Set 11 | hanzhong
# Processing Record 21 of Set 11 | acapulco
# Processing Record 22 of Set 11 | prince rupert
# Processing Record 23 of Set 11 | waipawa
# Processing Record 24 of Set 11 | lompoc
# Processing Record 25 of Set 11 | kendari
# Processing Record 26 of Set 11 | beringovskiy
# Processing Record 27 of Set 11 | ewo
# Processing Record 28 of Set 11 | la ronge
# Processing Record 29 of Set 11 | fitchburg
# Processing Record 30 of Set 11 | teknaf
# Processing Record 31 of Set 11 | salalah
# Processing Record 32 of Set 11 | luanda
# Processing Record 33 of Set 11 | gostyn
# Processing Record 34 of Set 11 | mangai
# Processing Record 35 of Set 11 | serebryanyy bor
# Processing Record 36 of Set 11 | tura
# Processing Record 37 of Set 11 | aden
# Processing Record 38 of Set 11 | smithers
# Processing Record 39 of Set 11 | windhoek
# Processing Record 40 of Set 11 | zhigansk
# Processing Record 41 of Set 11 | torbat-e jam
# Processing Record 42 of Set 11 | coos bay
# Processing Record 43 of Set 11 | cintalapa
# Processing Record 44 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | urumqi
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | dudinka
# Processing Record 49 of Set 11 | monroe
# Processing Record 50 of Set 11 | takoradi
# Processing Record 1 of Set 12 | garbolovo
# Processing Record 2 of Set 12 | vicar
# Processing Record 3 of Set 12 | aklavik
# Processing Record 4 of Set 12 | petaling jaya
# Processing Record 5 of Set 12 | tinyahuarco
# Processing Record 6 of Set 12 | brigantine
# Processing Record 7 of Set 12 | vizinga
# Processing Record 8 of Set 12 | mnogovershinnyy
# Processing Record 9 of Set 12 | diffa
# Processing Record 10 of Set 12 | naze
# Processing Record 11 of Set 12 | hakkari
# Processing Record 12 of Set 12 | ziro
# Processing Record 13 of Set 12 | kamenka
# Processing Record 14 of Set 12 | antofagasta
# Processing Record 15 of Set 12 | moree
# Processing Record 16 of Set 12 | oktyabrskiy
# Processing Record 17 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 18 of Set 12 | benton harbor
# Processing Record 19 of Set 12 | yabrud
# Processing Record 20 of Set 12 | hofn
# Processing Record 21 of Set 12 | saint-ambroise
# Processing Record 22 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 23 of Set 12 | pandan
# Processing Record 24 of Set 12 | sakaiminato
# Processing Record 25 of Set 12 | saurimo
# Processing Record 26 of Set 12 | makasar
# Processing Record 27 of Set 12 | freeport
# Processing Record 28 of Set 12 | nadym
# Processing Record 29 of Set 12 | coquimbo
# Processing Record 30 of Set 12 | bouillante
# Processing Record 31 of Set 12 | hammerfest
# Processing Record 32 of Set 12 | anchorage
# Processing Record 33 of Set 12 | kayanza
# Processing Record 34 of Set 12 | lincoln
# Processing Record 35 of Set 12 | french harbor
# Processing Record 36 of Set 12 | shihezi
# Processing Record 37 of Set 12 | zambezi
# Processing Record 38 of Set 12 | tecoanapa
# Processing Record 39 of Set 12 | muzhi
# Processing Record 40 of Set 12 | avera
# Processing Record 41 of Set 12 | kalmunai
# Processing Record 42 of Set 12 | ducheng
# Processing Record 43 of Set 12 | kinshasa
# Processing Record 44 of Set 12 | flinders
# Processing Record 45 of Set 12 | gairo
# Processing Record 46 of Set 12 | bodden town
# Processing Record 47 of Set 12 | krabi
# Processing Record 48 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 12 | quelimane
# Processing Record 50 of Set 12 | gizo
# Processing Record 1 of Set 13 | ngunguru
# Processing Record 2 of Set 13 | medicine hat
# Processing Record 3 of Set 13 | ziyang
# Processing Record 4 of Set 13 | rudnogorsk
# Processing Record 5 of Set 13 | mpanda
# Processing Record 6 of Set 13 | bulgan
# Processing Record 7 of Set 13 | dhidhdhoo
# Processing Record 8 of Set 13 | kletskaya
# Processing Record 9 of Set 13 | ulaanbaatar
# Processing Record 10 of Set 13 | kushima
# Processing Record 11 of Set 13 | concepcion
# Processing Record 12 of Set 13 | cantagallo
# Processing Record 13 of Set 13 | carnarvon
# Processing Record 14 of Set 13 | mogadishu
# Processing Record 15 of Set 13 | mbandaka
# Processing Record 16 of Set 13 | irati
# Processing Record 17 of Set 13 | berlevag
# Processing Record 18 of Set 13 | timberlake
# Processing Record 19 of Set 13 | bahia blanca
# Processing Record 20 of Set 13 | bandar-e lengeh
# Processing Record 21 of Set 13 | ponta delgada
# Processing Record 22 of Set 13 | portland
# Processing Record 23 of Set 13 | kula
# Processing Record 24 of Set 13 | buala
# Processing Record 25 of Set 13 | burica
# City not found. Skipping...
# Processing Record 26 of Set 13 | nador
# Processing Record 27 of Set 13 | monrovia
# Processing Record 28 of Set 13 | bay roberts
# Processing Record 29 of Set 13 | kodiak
# Processing Record 30 of Set 13 | port moresby
# Processing Record 31 of Set 13 | namibe
# Processing Record 32 of Set 13 | tanout
# Processing Record 33 of Set 13 | saraland
# Processing Record 34 of Set 13 | huilong
# Processing Record 35 of Set 13 | itatskiy
# Processing Record 36 of Set 13 | nemuro
# Processing Record 37 of Set 13 | glenluce
# Processing Record 38 of Set 13 | tiarei
# Processing Record 39 of Set 13 | argostolion
# Processing Record 40 of Set 13 | kushiro
# Processing Record 41 of Set 13 | rawicz
# Processing Record 42 of Set 13 | brownwood
# Processing Record 43 of Set 13 | fairbanks
# Processing Record 44 of Set 13 | yermish
# Processing Record 45 of Set 13 | libreville
# Processing Record 46 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 13 | phonhong
# Processing Record 48 of Set 13 | mundo nuevo
# Processing Record 49 of Set 13 | staryy nadym
# Processing Record 50 of Set 13 | oksbol
# Processing Record 1 of Set 14 | saint-francois
# Processing Record 2 of Set 14 | caceres
# Processing Record 3 of Set 14 | kharp
# Processing Record 4 of Set 14 | gladstone
# Processing Record 5 of Set 14 | tezu
# Processing Record 6 of Set 14 | tambopata
# Processing Record 7 of Set 14 | weligama
# Processing Record 8 of Set 14 | caibarien
# Processing Record 9 of Set 14 | eirunepe
# Processing Record 10 of Set 14 | west richland
# Processing Record 11 of Set 14 | qeshm
# Processing Record 12 of Set 14 | sao filipe
# Processing Record 13 of Set 14 | shimoda
# Processing Record 14 of Set 14 | khandyga
# Processing Record 15 of Set 14 | carballo
# Processing Record 16 of Set 14 | tshikapa
# Processing Record 17 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 14 | sehithwa
# Processing Record 19 of Set 14 | birao
# Processing Record 20 of Set 14 | praya
# Processing Record 21 of Set 14 | ambovombe
# Processing Record 22 of Set 14 | klyuchi
# Processing Record 23 of Set 14 | yatou
# Processing Record 24 of Set 14 | menongue
# Processing Record 25 of Set 14 | san patricio
# Processing Record 26 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 14 | hongjiang
# Processing Record 28 of Set 14 | kirkland lake
# Processing Record 29 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | kirakira
# Processing Record 31 of Set 14 | cayenne
# Processing Record 32 of Set 14 | manono
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | zalantun
# Processing Record 35 of Set 14 | port hedland
# Processing Record 36 of Set 14 | villa union
# Processing Record 37 of Set 14 | lima
# Processing Record 38 of Set 14 | tatawin
# Processing Record 39 of Set 14 | yining
# Processing Record 40 of Set 14 | kozhevnikovo
# Processing Record 41 of Set 14 | malpe
# Processing Record 42 of Set 14 | zlatoustovsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | nouadhibou
# Processing Record 44 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 14 | balkanabat
# Processing Record 46 of Set 14 | kinlochleven
# Processing Record 47 of Set 14 | the valley
# Processing Record 48 of Set 14 | atocha
# Processing Record 49 of Set 14 | ulladulla
# Processing Record 50 of Set 14 | wanning
# Processing Record 1 of Set 15 | fernley
# Processing Record 2 of Set 15 | roald
# Processing Record 3 of Set 15 | chabahar
# Processing Record 4 of Set 15 | bud
# Processing Record 5 of Set 15 | beisfjord
# Processing Record 6 of Set 15 | awjilah
# Processing Record 7 of Set 15 | caninde
# Processing Record 8 of Set 15 | half moon bay
# Processing Record 9 of Set 15 | asau
# Processing Record 10 of Set 15 | arequipa
# Processing Record 11 of Set 15 | canjulao
# Processing Record 12 of Set 15 | kilsyth
# Processing Record 13 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 15 | prachuap khiri khan
# Processing Record 15 of Set 15 | nyurba
# Processing Record 16 of Set 15 | ferme-neuve
# Processing Record 17 of Set 15 | carutapera
# Processing Record 18 of Set 15 | ossora
# Processing Record 19 of Set 15 | raudeberg
# Processing Record 20 of Set 15 | panchagarh
# Processing Record 21 of Set 15 | itarema
# Processing Record 22 of Set 15 | poya
# Processing Record 23 of Set 15 | batagay-alyta
# Processing Record 24 of Set 15 | zheleznodorozhnyy
# Processing Record 25 of Set 15 | mariinsk
# Processing Record 26 of Set 15 | along
# Processing Record 27 of Set 15 | linjiang
# Processing Record 28 of Set 15 | aranda de duero
# Processing Record 29 of Set 15 | gunjur
# Processing Record 30 of Set 15 | sabha
# Processing Record 31 of Set 15 | qasigiannguit
# Processing Record 32 of Set 15 | port-gentil
# Processing Record 33 of Set 15 | pointe-noire
# Processing Record 34 of Set 15 | warburton
# Processing Record 35 of Set 15 | grajau
# Processing Record 36 of Set 15 | garden city
# Processing Record 37 of Set 15 | kostomuksha
# Processing Record 38 of Set 15 | marana
# Processing Record 39 of Set 15 | miandrivazo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0        Vardo  70.3705   31.1107          few clouds     17.60        73
# 1       Itoman  26.1247  127.6694    scattered clouds     68.00        64
# 2  Komatipoort -25.4332   31.9548          light rain     73.00        98
# 3  Tuktoyaktuk  69.4541 -133.0374          light snow     -5.80        77
# 4       Turbat  26.0023   63.0440           clear sky     60.42        51
# 5     Cherskiy  68.7500  161.3000     overcast clouds     -5.19        91
# 6      Ushuaia -54.8000  -68.3000    scattered clouds     50.00        62
# 7      Rikitea -23.1203 -134.9692          light rain     80.31        76
# 8     Goderich  43.7501  -81.7165     overcast clouds     17.60        73
# 9      Mataura -46.1927  168.8643     overcast clouds     59.00        75
#
#    Cloudiness  Wind Speed Country
# 0          20        9.22      NO
# 1          40       20.71      JP
# 2          78        7.25      ZA
# 3          90       10.36      CA
# 4           0        4.07      PK
# 5          92        2.21      RU
# 6          40       12.66      AR
# 7          99       15.93      PF
# 8         100        8.05      CA
# 9         100       11.01      NZ

# %%
# Reorder columns
new_column_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Vardo      NO  70.3705   31.1107     17.60        73          20
# 1       Itoman      JP  26.1247  127.6694     68.00        64          40
# 2  Komatipoort      ZA -25.4332   31.9548     73.00        98          78
# 3  Tuktoyaktuk      CA  69.4541 -133.0374     -5.80        77          90
# 4       Turbat      PK  26.0023   63.0440     60.42        51           0
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1       20.71    scattered clouds
# 2        7.25          light rain
# 3       10.36          light snow
# 4        4.07           clear sky

# %%
# Create CSV file
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export city_data into CSV
city_data_df.to_csv(output_data_file, index_label= "City_ID")
